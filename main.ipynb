# %% [markdown]
# <a href="https://colab.research.google.com/github/Bethimen/EML_Grupo11_25-26/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

# Constantes para el reposittorio
REPO_NAME = "EML_GRUPO11_25-26"
REPO_URL = f"https://github.com/Bethimen/{REPO_NAME}.git"

#Colonar o actualizar el repositorio
if not os.path.exists(REPO_NAME):
    # !git clone {REPO_URL}
else:
    print("Repositorio ya existente. Actualizando...")
    # %cd {REPO_NAME}
    # !git pull
    # %cd ..
# Agregar el repositorio al path para importar módulos
sys.path.append(os.path.abspath(REPO_NAME))

#Instalar dependencias si el archivo requirements.txt existe
if os.path.exists(f"{REPO_NAME}/requirements.txt"):
    # !pip install -r {REPO_NAME}/requirements.txt
# Out:
# Repositorio ya existente. Actualizando...
# /content/EML_GRUPO11_25-26
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 5), reused 2 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 9.28 KiB | 68.00 KiB/s, done.
# From https://github.com/Bethimen/EML_GRUPO11_25-26
#    d77338c..4eddf8d  main       -> origin/main
# Updating d77338c..4eddf8d
# Fast-forward
#  .../parte3_evaluaci\303\263n.ipynb"                | 4750 ++++++++++----------
#  main.ipynb                                         |   54 +-
#  2 files changed, 2484 insertions(+), 2320 deletions(-)
# /content
# ...

# %%
# Ejecución en cadena del bandido de k-brazos
print("--- Ejecutando Bandido Normal ---")
bandido_normal = os.path.join(REPO_NAME, "eml_k_bandit-main/normal.ipynb")

# !jupyter nbconvert --to notebook --execute --inplace --ExecutePreprocessor.kernel_name=python3 {bandido_normal}

print("--- Ejecutando Bandido Binomial ---")
bandido_binomial = os.path.join(REPO_NAME, "eml_k_bandit-main/binomial.ipynb")

# !jupyter nbconvert --to notebook --execute --inplace --ExecutePreprocessor.kernel_name=python3 {bandido_binomial}

print("--- Ejecutando Bandido Bernoulli ---")
bandido_bernoulli = os.path.join(REPO_NAME, "eml_k_bandit-main/bernoulli.ipynb")

# !jupyter nbconvert --to notebook --execute --inplace --ExecutePreprocessor.kernel_name=python3 {bandido_bernoulli}


#print("--- Ejecutando Parte 2 ---")
parte2 = os.path.join(REPO_NAME, "RL_MetodosTabulares.ipynb")

# !jupyter nbconvert --to notebook --execute --inplace  {parte2}

print("--- Ejecutando Parte 3 ---")
parte3 = os.path.join(REPO_NAME, "Entornos_continuos/parte3_evaluación.ipynb")

# !jupyter nbconvert --to notebook --execute --inplace {parte3}
# Out:
# --- Ejecutando Bandido Normal ---
# [NbConvertApp] Converting notebook EML_GRUPO11_25-26/eml_k_bandit-main/normal.ipynb to notebook
# /usr/local/lib/python3.12/dist-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# ...

# %% [markdown]
# Parte 1:
#
#   - [Bandido normal](eml_k_bandit-main/normal.ipynb)
#
#   - [Bandido binomial](eml_k_bandit-main/binomial.ipynb)
#
#   - [Bandido bernoulli](eml_k_bandit-main/bernoulli.ipynb)
#
# [Parte 2](RL_MetodosTabulares.ipynb)
#
#
# [Parte 3](Entornos_continuos/parte3_evaluación.ipynb)
